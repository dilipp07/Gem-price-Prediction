# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\House-price-prediction\California-HousePrice-prediction\NoteBook\data.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779

# %%
df.shape
# Out:
# (26967, 11)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
### Missing values are found in depth

# %%
median_value=df['depth'].median()
df['depth'].fillna(median_value,inplace=True)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# I have handeled the missing value by replacing with median value

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
###There are 3 categorical feature and 7 nuemerical feature

# %%
##check for duplicated records

df.duplicated().sum()


###34 duplicated values are found
# Out:
# 34

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()

## I have dropped duplicated values
# Out:
# 0

# %%
numerical_columns=[features for features in df.columns if df[features].dtype!='O']
numerical_columns
# Out:
# ['carat', 'depth', 'table', 'x', 'y', 'z', 'price']

# %%
categorical_columns=[features for features in df.columns if df[features].dtype=='O']
categorical_columns
# Out:
# ['cut', 'color', 'clarity']

# %%
df[categorical_columns].describe()
# Out:
#           cut  color clarity
# count   26933  26933   26933
# unique      5      7       8
# top     Ideal      G     SI1
# freq    10805   5653    6565

# %%
for features in categorical_columns:
    print(df[features].value_counts())
# Out:
# Ideal        10805
# Premium       6886
# Very Good     6027
# Good          2435
# Fair           780
# Name: cut, dtype: int64
# G    5653
# E    4916
# F    4723
# H    4095
# D    3341
# I    2765
# J    1440
# Name: color, dtype: int64
# SI1     6565
# VS2     6093
# SI2     4564
# VS1     4087
# VVS2    2530
# VVS1    1839
# IF       891
# I1       364
# Name: clarity, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=1
for i in numerical_columns:
    sns.distplot(df[i],kde=True)
    print('\n')
    plt.show()
# Out:
# C:\Users\dilip\AppData\Local\Temp\ipykernel_20048\2662104936.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],kde=True)
# C:\Users\dilip\AppData\Local\Temp\ipykernel_20048\2662104936.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],kde=True)
# ...

# %%
for i in categorical_columns:
    sns.countplot(x=df[i])
    print('\n')
    plt.show()

# %%
## correlation
#refer correlation notebook in this folder
##x,y,z are internally correlated
###we can drop x,y,z
#we also see that depth is also not so much related to price so that we can also drop that one

# %%
#df.drop(labels==['x','y','z','depth'],axis=1,inplace=True)

##currently we are not dropping it

# %%
sns.pairplot(df)

# %%
df.head(3)
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype=object)

# %%
cut_map={"Fair":1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}

# %%
df['clarity'].unique()
# Out:
# array(['SI1', 'IF', 'VVS2', 'VS1', 'VVS1', 'VS2', 'SI2', 'I1'],
#       dtype=object)

# %%
clarity_map={'I1':1,'SI2':2,'SI1':3,'VS2':4,'VS1':5,'VVS2':6,'VVS1':7,'IF':8}

# %%
df['color'].unique()
# Out:
# array(['E', 'G', 'F', 'D', 'H', 'J', 'I'], dtype=object)

# %%
color_map={'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7}

# %%
df['cut']=df['cut'].map(cut_map)
df['clarity']=df['clarity'].map(clarity_map)
df['color']=df['color'].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0.30    5      2        3   62.1   58.0  4.27  4.29  2.66    499
# 1   0.33    4      4        8   60.8   58.0  4.42  4.46  2.70    984
# 2   0.90    3      2        6   62.2   60.0  6.04  6.12  3.78   6289
# 3   0.42    5      3        5   61.6   56.0  4.82  4.80  2.96   1082
# 4   0.31    5      3        7   60.4   59.0  4.35  4.43  2.65    779
